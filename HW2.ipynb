# %% [markdown]
# # ДЗ 2 Оцениваемое (HW2)
# ## Задание 1
# Дан текст (можно взять любой, необязательно этот):
#
# > варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг
#
# Необходимо выделить все биграммы в этом тексте и сохранить их список в какую-либо переменную. **Биграммы** -- это пары стоящих рядом слов, например, "варкалось хливкие", "хливкие шорьки"  и т.д.

# %%
text = """варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг"""
words = text.split()
# выделям биграммы 
bigrams = []
for i in range(len(words)-1): 
    bigram = tuple([words[i], words[i + 1]])
# добавляем биграммы в список
    bigrams.append(bigram)
    print(bigram)
# Out:
# ('варкалось', 'хливкие')
# ('хливкие', 'шорьки')
# ('шорьки', 'пырялись')
# ('пырялись', 'по')
# ('по', 'наве')
# ('наве', 'и')
# ('и', 'хрюкотали')
# ('хрюкотали', 'зелюки')
# ('зелюки', 'как')
# ('как', 'мюмзики')
# ('мюмзики', 'в')
# ('в', 'мове')
# ('мове', 'о')
# ('о', 'бойся')
# ('бойся', 'бармаглота')
# ('бармаглота', 'сын')
# ('сын', 'он')
# ('он', 'так')
# ('так', 'свирлеп')
# ('свирлеп', 'и')
# ('и', 'дик')
# ('дик', 'а')
# ('а', 'в')
# ('в', 'глyще')
# ('глyще', 'рымит')
# ('рымит', 'исполин')
# ('исполин', 'злопастный')
# ('злопастный', 'брандашмыг')

# %% [markdown]
# ## Задание 2
# 1. Если вы не делали git pull или git clone: cкачать архив с текстовыми файлами [отсюда](https://www.dropbox.com/s/uvf5kuet958p0xt/poems.rar?dl=0) и распаковать его. Если делали, то все нужные файлы уже есть в папке poems.
# 2. Распечатать текущую директорию и список всех файлов и папок в ней. Посчитать и распечатать количество файлов.
# 3. Пройтись циклом по рабочей директории, читая содержимое каждого файла и записывая его в новый файл poems.txt По завершении цикла должен получиться файл со всеми стихотворениями!

# %%
# распечатываем текущую директорию
import os
print(os.getcwd())
# распечатываем список всех файлов и папок в текущей директории
for file in os.listdir('.'):
    print(file)
# считаем и распечатываем кол-во файлов
print(len(file))
# Out:
# C:\Users\Людмила\Desktop\python-dh-hw
# .git
# .gitignore
# .ipynb
# .ipynb_checkpoints
# class LAST.ipynb
# file new
# hello.txt
# HW1.ipynb
# HW2.ipynb
# poems
# poems.txt
# README.md
# sem_7_Files.ipynb
# 17

# %%
# проходим циклом по директории со стихами
for root, dirs, files in os.walk('C:/Users/Людмила/Desktop/python-dh-hw/poems'):
# читаем содержимое каждого файла
    for name in files:
        with open(os.path.join(root, name), 'r', encoding='utf-8') as f:
            poem = f.read()
# и записывем стихи в новый файл poems.txt
        with open('poems.txt', 'a', encoding='utf-8') as f:
            f.write(poem + '\n')
# выводим итоговый текст файла со всеми стихами, чтобы проверить себя 
with open('poems.txt', 'r', encoding='utf-8') as f:
    outcome = f.read()
    print(outcome)
# Out:
# а боль у вас какого рода
# спросил дежурный врач а я
# как на духу она ответил
# моя
# американский чорный ворон
# как наш красив и голосист
# но попроси не виться сразу
# расист
# на спиритическом сеансе
# желая водки и еды
# привычно вызывали духов
# деды
# мы б вас охотно пропустили
# с ручною кладью но пока
# она у вас недопустимо
# дика
# ночь улица фонарь аптека
# вдруг вспомнил что утюг включон
# акетпа ираноф ацилу
# и ьчон
# приходит муж домой пораньше
# измену в нём предположив
# а шрёдингер в шкафу не мёртв и
# не жив
# кот по цепи идёт направо
# и упирается в щиток
# а от щитка идя налево
# он ток
# загримирован под медведя
# кот гнал ди каприо по льду
# и все кричали оскар лео
# польду
# пушок пушок кричит хозяйка
# а мы сидим невдалеке
# и ухмыляемся а рыльца
# в пушке
# идут по лесу братья гриммы
# и вырубают топором
# всех тех кто был уже написан
# перром
# третьеразрядный королевич
# побил дракона как герой
# царевну вызволил и сдал на
# второй
# на платье новое дивится
# и восторгается страна
# вдруг кто то крикнул а король то
# она
# а если принц тебя обидит
# поверь тогда ему конец
# ведь я не крёстная а крёстный
# отец
# клюку на рынке выбирая
# яга сказала дайте две
# я кэмээс по скандинавской
# ходьбе

# %% [markdown]
# ## Задание 3
# **Удивительная кошка**
#
# _Несчастная кошка порезала лапу- <br>
# Сидит, и ни шагу не может ступить.<br>
# Скорей, чтобы вылечить кошкину лапу<br>
# Воздушные шарики надо купить!<br>
# <br>
# И сразу столпился народ на дороге-<br>
# Шумит, и кричит, и на кошку глядит.<br>
# А кошка отчасти идет по дороге,<br>
# Отчасти по воздуху плавно летит!<br>_
#
# 1. Скопировать текст, сохранить его в переменную.
# 2. Узнать длину текста в символах.
# 3. Очистить текст от пунктуации, используя list compehensions. На выходе должен получиться список слов.
# 4. Объединить слова из получившегося списка в строку через пробел.
# 4. С помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру. На выходе должен получиться список из всех слов стихотворения, написанных с маленькой буквы (не только те, которые изначально были с маленькой буквы, а все).
# 5. Узнать длину текста в словах.
# 6. Узнать количество уникальных слов.
# 7. Распечатать последние 10 слов.
# 8. Соединить полученный в пункте 3 список в строку. Слова в строке должны быть написаны через знак переноса строки.
# 9. Распечатать с 20 по 30 символ этой строки (включительно).
# 10. Разбить текст на биграммы, записать их в переменную и посчитать частотность каждой биграммы. Биграммы должны быть в виде списка кортежей.

# %%
poem = """ Удивительная кошка

Несчастная кошка порезала лапу-
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!"""

# узнаём длину текста в символах.
print(len(poem))
# Out:
# 290

# %%
# очищаем текст от пунктуации, используя list compehensions
words = [word.strip("!?.,-") for word in poem.split()]
print(words)
# Out:
# ['Удивительная', 'кошка', 'Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
# объединяем слова из получившегося списка в строку через пробел
s2 = ' '.join(words)
print(s2)
# Out:
# Удивительная кошка Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит

# %%
# с помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру. На выходе должен получиться список из всех слов стихотворения, написанных с маленькой буквы (не только те, которые изначально были с маленькой буквы, а все).
lowerpoem = [w if w.islower() else w.lower()  for w in s2.split()]
print(lowerpoem)
# Out:
# ['удивительная', 'кошка', 'несчастная', 'кошка', 'порезала', 'лапу', 'сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'воздушные', 'шарики', 'надо', 'купить', 'и', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'а', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
# узнать длину текста в словах.
print(len(lowerpoem))
# Out:
# 46

# %%
# узнать количество уникальных слов
unique = set(lowerpoem)
print(len(unique))
# Out:
# 36

# %%
# распечатать последние 10 слов
print(lowerpoem[-10:])
# Out:
# ['кошка', 'отчасти', 'идет', 'по', 'дороге', 'отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
# соединить полученный в пункте 3 список в строку. Слова в строке должны быть написаны через знак переноса строки
st = '\n'.join(words)
print(st)
# Out:
# Удивительная
# кошка
# Несчастная
# кошка
# порезала
# лапу
# Сидит
# и
# ни
# шагу
# не
# может
# ступить
# Скорей
# чтобы
# вылечить
# кошкину
# лапу
# Воздушные
# шарики
# надо
# купить
# И
# сразу
# столпился
# народ
# на
# дороге
# Шумит
# и
# кричит
# и
# на
# кошку
# глядит
# А
# кошка
# отчасти
# идет
# по
# дороге
# Отчасти
# по
# воздуху
# плавно
# летит

# %%
# распечатать с 20 по 30 символ этой строки (включительно).
print(st[19:30])
# Out:
# Несчастная

# %%
# разбить текст на биграммы, записать их в переменную 
bigrams2 = []
for i in range(len(words)-1): 
    bigram = tuple([words[i], words[i + 1]]) 
    bigrams2.append(bigram)

# %%
# посчитать частотность каждой биграммы. Биграммы должны быть в виде списка кортежей.
for w in bigrams2:
    print('Биграмма', w, 'присутствует в кол-ве:', bigrams2.count(w))
# Out:
# Биграмма ('Удивительная', 'кошка') присутствует в кол-ве: 1
# Биграмма ('кошка', 'Несчастная') присутствует в кол-ве: 1
# Биграмма ('Несчастная', 'кошка') присутствует в кол-ве: 1
# Биграмма ('кошка', 'порезала') присутствует в кол-ве: 1
# Биграмма ('порезала', 'лапу') присутствует в кол-ве: 1
# Биграмма ('лапу', 'Сидит') присутствует в кол-ве: 1
# Биграмма ('Сидит', 'и') присутствует в кол-ве: 1
# Биграмма ('и', 'ни') присутствует в кол-ве: 1
# Биграмма ('ни', 'шагу') присутствует в кол-ве: 1
# Биграмма ('шагу', 'не') присутствует в кол-ве: 1
# Биграмма ('не', 'может') присутствует в кол-ве: 1
# Биграмма ('может', 'ступить') присутствует в кол-ве: 1
# Биграмма ('ступить', 'Скорей') присутствует в кол-ве: 1
# Биграмма ('Скорей', 'чтобы') присутствует в кол-ве: 1
# Биграмма ('чтобы', 'вылечить') присутствует в кол-ве: 1
# Биграмма ('вылечить', 'кошкину') присутствует в кол-ве: 1
# Биграмма ('кошкину', 'лапу') присутствует в кол-ве: 1
# Биграмма ('лапу', 'Воздушные') присутствует в кол-ве: 1
# Биграмма ('Воздушные', 'шарики') присутствует в кол-ве: 1
# Биграмма ('шарики', 'надо') присутствует в кол-ве: 1
# Биграмма ('надо', 'купить') присутствует в кол-ве: 1
# Биграмма ('купить', 'И') присутствует в кол-ве: 1
# Биграмма ('И', 'сразу') присутствует в кол-ве: 1
# Биграмма ('сразу', 'столпился') присутствует в кол-ве: 1
# Биграмма ('столпился', 'народ') присутствует в кол-ве: 1
# Биграмма ('народ', 'на') присутствует в кол-ве: 1
# Биграмма ('на', 'дороге') присутствует в кол-ве: 1
# Биграмма ('дороге', 'Шумит') присутствует в кол-ве: 1
# Биграмма ('Шумит', 'и') присутствует в кол-ве: 1
# Биграмма ('и', 'кричит') присутствует в кол-ве: 1
# Биграмма ('кричит', 'и') присутствует в кол-ве: 1
# Биграмма ('и', 'на') присутствует в кол-ве: 1
# Биграмма ('на', 'кошку') присутствует в кол-ве: 1
# Биграмма ('кошку', 'глядит') присутствует в кол-ве: 1
# Биграмма ('глядит', 'А') присутствует в кол-ве: 1
# Биграмма ('А', 'кошка') присутствует в кол-ве: 1
# Биграмма ('кошка', 'отчасти') присутствует в кол-ве: 1
# Биграмма ('отчасти', 'идет') присутствует в кол-ве: 1
# Биграмма ('идет', 'по') присутствует в кол-ве: 1
# Биграмма ('по', 'дороге') присутствует в кол-ве: 1
# Биграмма ('дороге', 'Отчасти') присутствует в кол-ве: 1
# Биграмма ('Отчасти', 'по') присутствует в кол-ве: 1
# Биграмма ('по', 'воздуху') присутствует в кол-ве: 1
# Биграмма ('воздуху', 'плавно') присутствует в кол-ве: 1
# Биграмма ('плавно', 'летит') присутствует в кол-ве: 1
