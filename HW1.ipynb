# %%
n = int(input("Сколько пингвинов нарисовать? (от 1 до 9): "))
if n < 1 or n > 9:
    print("Можно нарисовать от 1 до 9 пингвинов")
else:
    print ("   _~_    " * n)
    print ("  (o o)   " * n)
    print (" /  V  \\  " * n)
    print ("/(  _  )\\ " * n)
    print ("  ^^ ^^   " * n)
# Out:
# Сколько пингвинов нарисовать? (от 1 до 9): 4
#    _~_       _~_       _~_       _~_
#   (o o)     (o o)     (o o)     (o o)
#  /  V  \   /  V  \   /  V  \   /  V  \
# /(  _  )\ /(  _  )\ /(  _  )\ /(  _  )\
#   ^^ ^^     ^^ ^^     ^^ ^^     ^^ ^^

# %%
userline = input("Вставьте строку: ")
words = userline.split()
print ("Количество слов: %s" % len(words))
print ("Количество символов: %s" % len(userline))
# Out:
# Вставьте строку: Ницше одним из первых подверг сомнению единство субъекта, причинность воли,
# Количество слов: 10
# Количество символов: 75

# %%
s = input("Вставьте строку, состоящую из более 20 символов: ")
print(s[2])
print(s[-2])
print(s[0:5])
print(s[0:-2])
print(s[0::2])   
print(s[1::2])
print(s[::-1])
print(s[-1::-2])
print(len(s))
# Out:
# Вставьте строку, состоящую из более 20 символов: Ненавижу есть бутерброды с маслом
# н
# о
# Ненав
# Ненавижу есть бутерброды с масл
# Ннвж сьбтррд  алм
# еаиует уебоысмсо
# молсам с ыдорбретуб ьтсе уживанеН
# мла  дрртбьс жвнН
# 33

# %%
line1 = input("Введите первое слово\n")
if (line1[0:]) == (line1[::-1]):
    print("YES")
else:
    print("NO")
line2 = input("Введите второе слово\n")
if (line2[0:]) == (line2[::-1]):
    print("YES")
else:
    print("NO")
# Out:
# Введите первое слово
# анна
# YES
# Введите второе слово
# масло
# NO

# %%
text = """законы физики рядом с черной дырой уже не работают в том представлении в котором мы привыкли 
пространство время искривляется и все события протекают уже совсем по другому 
словно пылесос черная дыра поглощает все что находится около нее планеты астероиды свет и прочее 
ранее считалось что черная дыра ничего не излучает но как доказал стивен хокинг черная дыра излучает антивещество 
то есть поедает вещество и выделяет антивещество 
ранее думали что если кинуть в черную дыру человека то ему труба порвет на субатомы 
но как оказалось по некоторым уравнениям есть определенные траектории путешествия сквозь черную дыру чтоб чувствовать себя нормально 
правда не ясно что будет за ней другой мир или ничего 
область вокруг черной дыры которая интересна называется горизонтом событий 
если туда полететь не зная волшебное уравнение то будет конечно не очень 
наблюдатель будет видеть как космический корабль влетает в горизонт событий и крайне медленно потом отдаляется пока не застынет в центре
у самого же космонавта дела будут идти совсем по другому 
искривленное пространство будет лепить из него как из пластилина различные формы пока наконец не разорвет все на субатомы 
но для внешнего наблюдателя космонавт навсегда останется улыбающимся и махающим в иллюминатор застывшим изображением"""
ms = text.split()
userword = input("Введите слово: ")
if userword not in text:
    ms.append(userword)
    print("Слово %s добавлено" %(userword))
else:
    numberw = ms.count(userword)
    print("Слово '%s' встречается в тексте %s раз" %(userword, numberw))
# Out:
# Введите слово: не
# Слово 'не' встречается в тексте 7 раз
